# %% [markdown]
# <a href="https://colab.research.google.com/github/dextersherry/CarPlanet/blob/main/InTheLoop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello shresth")
# Out:
# hello shresth
